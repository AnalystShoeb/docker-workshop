# %%
import pandas as pd
from sqlalchemy import create_engine
import click

# %%
# !wget https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Out:
# --2026-03-06 08:29:52--  https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv
# Resolving github.com (github.com)... 20.207.73.82
# Connecting to github.com (github.com)|20.207.73.82|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/513814948/5a2cc2f5-b4cd-4584-9c62-a6ea97ed0e6a?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-06T09%3A03%3A41Z&rscd=attachment%3B+filename%3Dtaxi_zone_lookup.csv&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-06T08%3A02%3A44Z&ske=2026-03-06T09%3A03%3A41Z&sks=b&skv=2018-11-09&sig=jIdQEkf0ooxDJKCOX%2BTaDYtyWgFJFmIb0Zy9om7oeLc%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3Mjc4NjA5MiwibmJmIjoxNzcyNzg1NzkyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.-cKI-Sg9nMr6kzswID_XqkGFrddSMt7vdbYxnTs4E4s&response-content-disposition=attachment%3B%20filename%3Dtaxi_zone_lookup.csv&response-content-type=application%2Foctet-stream [following]
# --2026-03-06 08:29:52--  https://release-assets.githubusercontent.com/github-production-release-asset/513814948/5a2cc2f5-b4cd-4584-9c62-a6ea97ed0e6a?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-03-06T09%3A03%3A41Z&rscd=attachment%3B+filename%3Dtaxi_zone_lookup.csv&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-03-06T08%3A02%3A44Z&ske=2026-03-06T09%3A03%3A41Z&sks=b&skv=2018-11-09&sig=jIdQEkf0ooxDJKCOX%2BTaDYtyWgFJFmIb0Zy9om7oeLc%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3Mjc4NjA5MiwibmJmIjoxNzcyNzg1NzkyLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.-cKI-Sg9nMr6kzswID_XqkGFrddSMt7vdbYxnTs4E4s&response-content-disposition=attachment%3B%20filename%3Dtaxi_zone_lookup.csv&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12322 (12K) [application/octet-stream]
# Saving to: ‘taxi_zone_lookup.csv.3’
#
# taxi_zone_lookup.cs 100%[===================>]  12.03K  --.-KB/s    in 0.004s
#
# 2026-03-06 08:29:52 (3.35 MB/s) - ‘taxi_zone_lookup.csv.3’ saved [12322/12322]

# %%
prefix = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/'
url = f'{prefix}/taxi_zone_lookup.csv'
df_zones = pd.read_csv(url)

# %%
df_zones = pd.read_csv('taxi_zone_lookup.csv')

# %%
df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
len(df_zones)
# Out:
# 265

# %%
engine = create_engine(f'postgresql://root:root@localhost:5432/ny_taxi')

# %%
df_zones.to_sql(name='zones',con=engine, if_exists='replace')
# Out:
# 265
